# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.preprocessing import StandardScaler 
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
train_data.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
data = [train_data, test_data]
for df in data:
    df.loc[df['avg_training_score'] > 73,'tr_score_cat'] = 'H'
    df.loc[df['avg_training_score'] < 60,'tr_score_cat'] = 'L'
    df.loc[(df['avg_training_score'] <= 73) & (df['avg_training_score'] >=
                                               60),'tr_score_cat'] = 'M'

# %%
r1 = ['region_1','region_10','region_11','region_12','region_13','region_14','region_15','region_16','region_31','region_30','region_27','region_26','region_20','region_2','region_19','region_8']
r2 = ['region_17','region_4','region_7','region_3','region_28','region_25','region_23','region_22']
r3 = ['region_18','region_9','region_6','region_5','region_34','region_33','region_32','region_29','region_24','region_21']

# %%
for df in data:
    df.loc[df['region'].isin(r1) ,'region_gp'] = 1
    df.loc[df['region'].isin(r2) ,'region_gp'] = 2
    df.loc[df['region'].isin(r3) ,'region_gp'] = 3

# %%
for df in data:
    df['KPI_AWard']  = df['KPIs_met >80%'] + df['awards_won?']
    df['KPI_Rating']  = df['KPIs_met >80%'] + df['previous_year_rating']
    df['AWard_Rating']  = df['awards_won?'] + df['previous_year_rating']

# %%
#numeric = ['avg_training_score', 'age', 'length_of_service', 'no_of_trainings']
#category = ['KPIs_met >80%', 'awards_won?' ,'previous_year_rating', 'department', 'region', 'education', 'gender', 'recruitment_channel']

# %%
#for i in category:
    #train_data[i] = train_data[i].astype('category')
    #test_data[i] = test_data[i].astype('category')

#train_data['is_promoted'] = train_data['is_promoted'].astype('category')

# %%
train_data.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# tr_score_cat               0
# region_gp                  0
# KPI_AWard                  0
# KPI_Rating              4124
# AWard_Rating            4124
# dtype: int64

# %%
test_data.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# tr_score_cat               0
# region_gp                  0
# KPI_AWard                  0
# KPI_Rating              1812
# AWard_Rating            1812
# dtype: int64

# %%
# Filling Null values
#train_data['education'] = train_data['education'].cat.add_categories('No Degree')
train_data['education'].fillna('No Degree',inplace = True)
#test_data['education'] = test_data['education'].cat.add_categories('No Degree')
test_data['education'].fillna('No Degree',inplace = True)

# %%
# Filling Null values
#train_data['previous_year_rating'] = train_data['previous_year_rating'].cat.add_categories('-999')
train_data['previous_year_rating'].fillna(-999,inplace = True)
#test_data['previous_year_rating'] = test_data['previous_year_rating'].cat.add_categories('-999')
test_data['previous_year_rating'].fillna(-999,inplace = True)

# %%
# Filling Null values
#train_data['previous_year_rating'] = train_data['previous_year_rating'].cat.add_categories('-999')
train_data['KPI_Rating'].fillna(-999,inplace = True)
#test_data['previous_year_rating'] = test_data['previous_year_rating'].cat.add_categories('-999')
test_data['KPI_Rating'].fillna(-999,inplace = True)

# %%
# Filling Null values
#train_data['previous_year_rating'] = train_data['previous_year_rating'].cat.add_categories('-999')
train_data['AWard_Rating'].fillna(-999,inplace = True)
#test_data['previous_year_rating'] = test_data['previous_year_rating'].cat.add_categories('-999')
test_data['AWard_Rating'].fillna(-999,inplace = True)

# %%
train_data.isnull().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# is_promoted             0
# tr_score_cat            0
# region_gp               0
# KPI_AWard               0
# KPI_Rating              0
# AWard_Rating            0
# dtype: int64

# %%
# Scaling
#scaler = StandardScaler()
#for i in numeric:
#   train_data[i] = scaler.fit_transform(train_data[i].values.reshape(-1,1))
#   test_data[i] = scaler.fit_transform(test_data[i].values.reshape(-1,1))

# %%
mean_cols = ['KPIs_met >80%', 'awards_won?','previous_year_rating', 'department','region', 'education','gender', 'recruitment_channel']
for i in mean_cols:
    means = train_data.groupby(i).is_promoted.mean()
    train_data[i + "mean_target"] = train_data[i].map(means)
    test_data[i + "mean_target"] = test_data[i].map(means)

# %%
train_data.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  ...  KPI_Rating  AWard_Rating  KPIs_met >80%mean_target  \
# 0                  8  ...         6.0           5.0                  0.169094
# 1                  4  ...         5.0           5.0                  0.039587
# 2                  7  ...         3.0           3.0                  0.039587
# 3                 10  ...         1.0           1.0                  0.039587
# 4                  2  ...         3.0           3.0                  0.039587
#
#    awards_won?mean_target previous_year_ratingmean_target  \
# 0                0.076749                        0.163615
# 1                0.076749                        0.163615
# 2                0.076749                        0.072779
# 3                0.076749                        0.014141
# 4                0.076749                        0.072779
#
#    departmentmean_target  regionmean_target  educationmean_target  \
# 0               0.072031           0.106546              0.098559
# 1               0.090148           0.114188              0.082031
# 2               0.072031           0.060641              0.082031
# 3               0.072031           0.116596              0.082031
# 4               0.107593           0.063274              0.082031
#
#    gendermean_target  recruitment_channelmean_target
# 0           0.089934                        0.085013
# 1           0.083151                        0.083952
# 2           0.083151                        0.085013
# 3           0.083151                        0.083952
# 4           0.083151                        0.083952
#
# [5 rows x 27 columns]

# %%
#LabelEncoding
category_encode = ['previous_year_rating', 'department', 'region', 'education', 'gender', 'recruitment_channel','tr_score_cat','region_gp']
le = LabelEncoder()
for i in category_encode:
    train_data[i] = le.fit_transform(train_data[i])
    test_data[i] = le.transform(test_data[i])

# %%
#droping employee_id
train_data.drop('employee_id', axis=1, inplace=True)
Emp_ID = test_data['employee_id']
test_data.drop('employee_id', axis=1, inplace=True)

# %%
train_data.head()
# Out:
#    department  region  education  gender  recruitment_channel  \
# 0           7      31          2       0                    2
# 1           4      14          0       1                    0
# 2           7      10          0       1                    2
# 3           7      15          0       1                    0
# 4           8      18          0       1                    0
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                     5                  8
# 1                1   30                     5                  4
# 2                1   34                     3                  7
# 3                2   39                     1                 10
# 4                1   45                     3                  2
#
#    KPIs_met >80%  ...  KPI_Rating  AWard_Rating  KPIs_met >80%mean_target  \
# 0              1  ...         6.0           5.0                  0.169094
# 1              0  ...         5.0           5.0                  0.039587
# 2              0  ...         3.0           3.0                  0.039587
# 3              0  ...         1.0           1.0                  0.039587
# 4              0  ...         3.0           3.0                  0.039587
#
#    awards_won?mean_target  previous_year_ratingmean_target  \
# 0                0.076749                         0.163615
# 1                0.076749                         0.163615
# 2                0.076749                         0.072779
# 3                0.076749                         0.014141
# 4                0.076749                         0.072779
#
#    departmentmean_target  regionmean_target  educationmean_target  \
# 0               0.072031           0.106546              0.098559
# 1               0.090148           0.114188              0.082031
# 2               0.072031           0.060641              0.082031
# 3               0.072031           0.116596              0.082031
# 4               0.107593           0.063274              0.082031
#
#    gendermean_target  recruitment_channelmean_target
# 0           0.089934                        0.085013
# 1           0.083151                        0.083952
# 2           0.083151                        0.085013
# 3           0.083151                        0.083952
# 4           0.083151                        0.083952
#
# [5 rows x 26 columns]

# %%
test_data.head()
# Out:
#    department  region  education  gender  recruitment_channel  \
# 0           8      18          0       1                    2
# 1           2      28          0       0                    0
# 2           7       4          0       1                    0
# 3           5      11          0       0                    0
# 4           1      21          0       1                    2
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   24                     0                  1
# 1                1   31                     3                  5
# 2                1   31                     1                  4
# 3                3   31                     2                  9
# 4                1   30                     4                  7
#
#    KPIs_met >80%  ...  KPI_Rating  AWard_Rating  KPIs_met >80%mean_target  \
# 0              1  ...      -999.0        -999.0                  0.169094
# 1              0  ...         3.0           3.0                  0.039587
# 2              0  ...         1.0           1.0                  0.039587
# 3              0  ...         2.0           2.0                  0.039587
# 4              0  ...         4.0           4.0                  0.039587
#
#    awards_won?mean_target  previous_year_ratingmean_target  \
# 0                0.076749                         0.082202
# 1                0.076749                         0.072779
# 2                0.076749                         0.014141
# 3                0.076749                         0.042840
# 4                0.076749                         0.079376
#
#    departmentmean_target  regionmean_target  educationmean_target  \
# 0               0.107593           0.063274              0.082031
# 1               0.056245           0.144451              0.082031
# 2               0.072031           0.086858              0.082031
# 3               0.096386           0.080126              0.082031
# 4               0.081230           0.043260              0.082031
#
#    gendermean_target  recruitment_channelmean_target
# 0           0.083151                        0.085013
# 1           0.089934                        0.083952
# 2           0.083151                        0.083952
# 3           0.089934                        0.083952
# 4           0.083151                        0.085013
#
# [5 rows x 25 columns]

# %%
plt.figure(figsize=(30,25))
sns.heatmap(train_data.corr(),annot = True)

# %%
# Based on the above correlation lets remove some columns
col_to_remove = ['KPI_AWard','KPIs_met >80%mean_target','awards_won?mean_target','AWard_Rating','gendermean_target']
for i in col_to_remove:
    train_data.drop(i,axis=1,inplace = True)
    test_data.drop(i,axis=1, inplace = True)

# %%
train_data.head()

# %%
# train test split
X = train_data.drop("is_promoted",axis=1)
Y = train_data["is_promoted"]
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=42, stratify = Y)

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\xgboost\core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \

# %%
params = {
    # Parameters that we are going to tune.
    'max_depth':6,
    'min_child_weight': 1,
    'eta':.3,
    'subsample': 1,
    'colsample_bytree': 1,
    # Other parameters
    'objective':'reg:logistic',
}

# %%
params['eval_metric'] = "logloss"
num_boost_round = 999

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=100
)
# Out:
# [0]	Test-logloss:0.496618
# Will train until Test-logloss hasn't improved in 100 rounds.
# [1]	Test-logloss:0.389314
# [2]	Test-logloss:0.323785
# [3]	Test-logloss:0.275777
# [4]	Test-logloss:0.244353
# [5]	Test-logloss:0.223688
# [6]	Test-logloss:0.209025
# [7]	Test-logloss:0.19864
# [8]	Test-logloss:0.188871
# [9]	Test-logloss:0.183615
# [10]	Test-logloss:0.17964
# [11]	Test-logloss:0.17646
# [12]	Test-logloss:0.174764
# [13]	Test-logloss:0.173214
# [14]	Test-logloss:0.172176
# [15]	Test-logloss:0.170348
# [16]	Test-logloss:0.169374
# [17]	Test-logloss:0.168788
# [18]	Test-logloss:0.168545
# [19]	Test-logloss:0.167602
# [20]	Test-logloss:0.167717
# [21]	Test-logloss:0.167169
# [22]	Test-logloss:0.166986
# [23]	Test-logloss:0.16694
# [24]	Test-logloss:0.166765
# [25]	Test-logloss:0.166563
# [26]	Test-logloss:0.166437
# [27]	Test-logloss:0.166614
# [28]	Test-logloss:0.166589
# [29]	Test-logloss:0.166613
# [30]	Test-logloss:0.166474
# [31]	Test-logloss:0.166514
# [124]	Test-logloss:0.175095
# [125]	Test-logloss:0.175248
# [126]	Test-logloss:0.175284
# [127]	Test-logloss:0.175318
# [128]	Test-logloss:0.175373
# [129]	Test-logloss:0.175475
# [130]	Test-logloss:0.175768
# [131]	Test-logloss:0.176116
# [132]	Test-logloss:0.176116
# [133]	Test-logloss:0.176267
# [134]	Test-logloss:0.176384
# [135]	Test-logloss:0.1765
# [136]	Test-logloss:0.176487
# Stopping. Best iteration:
# [36]	Test-logloss:0.165755

# %%
print("Best Logloss: {:.2f} with {} rounds".format(
                 model.best_score,
                 model.best_iteration+1))
# Out:
# Best Logloss: 0.17 with 37 rounds

# %%
dtrain = xgb.DMatrix(train_data.drop("is_promoted",axis=1), label=train_data['is_promoted'])
dtest = xgb.DMatrix(test_data)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\xgboost\core.py:588: FutureWarning: Series.base is deprecated and will be removed in a future version
#   data.base is not None and isinstance(data, np.ndarray) \

# %%
cv_results = xgb.cv(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    seed=42,
    nfold=5,
    metrics={'logloss'},
    early_stopping_rounds=100
)
cv_results
# Out:
#     train-logloss-mean  train-logloss-std  test-logloss-mean  test-logloss-std
# 0             0.496178           0.000551           0.496963          0.001869
# 1             0.387857           0.000573           0.389141          0.002881
# 2             0.318412           0.001308           0.320106          0.004019
# 3             0.272220           0.001531           0.274461          0.004076
# 4             0.240866           0.001492           0.243482          0.004457
# 5             0.219238           0.001024           0.222207          0.005339
# 6             0.204071           0.000877           0.207594          0.005749
# 7             0.192183           0.001904           0.196068          0.005233
# 8             0.183574           0.002108           0.188025          0.005407
# 9             0.177313           0.001463           0.182264          0.005947
# 10            0.172691           0.001624           0.178041          0.005772
# 11            0.169202           0.001747           0.175016          0.005755
# 12            0.166209           0.001614           0.172621          0.005724
# 13            0.163730           0.001319           0.170844          0.005961
# 14            0.162143           0.001245           0.169935          0.005857
# 15            0.160463           0.001549           0.168970          0.005887
# 16            0.158815           0.001637           0.167833          0.005937
# 17            0.157771           0.001552           0.167345          0.005840
# 18            0.157223           0.001550           0.167157          0.005827
# 19            0.156503           0.001500           0.166955          0.005686
# 20            0.155582           0.001919           0.166621          0.005413
# 21            0.154560           0.001820           0.166373          0.005431
# 22            0.153963           0.001801           0.166164          0.005418
# 23            0.153351           0.001752           0.165947          0.005395
# 24            0.152618           0.001829           0.165716          0.005276
# 25            0.151643           0.001822           0.165609          0.005187
# 26            0.150867           0.001871           0.165406          0.005092
# 27            0.150112           0.001585           0.165184          0.005147
# 28            0.149585           0.001646           0.165027          0.005078
# 29            0.149029           0.001865           0.165133          0.005120
# 30            0.148510           0.001797           0.164962          0.005269
# 31            0.147878           0.001808           0.164958          0.005586
# 32            0.147469           0.001919           0.164800          0.005469
# 33            0.146915           0.001874           0.164822          0.005441
# 34            0.146207           0.001832           0.164750          0.005398
# 35            0.145718           0.001702           0.164722          0.005339
# 36            0.145085           0.001734           0.164697          0.005408
# 37            0.144611           0.001610           0.164627          0.005345

# %%
cv_results['test-logloss-mean'].min()
# Out:
# 0.16462700000000002

# %%
# You can try wider intervals with a larger step between
# each value and then narrow it down. Here after several
# iteration I found that the optimal value was in the
# following ranges.
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(3,10)
    for min_child_weight in range(2,8)
]

# %%
# Define initial best params and Logloss
min_logloss = float("Inf")
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'logloss'},
        early_stopping_rounds=100
    )
    # Update best MAE
    mean_logloss = cv_results['test-logloss-mean'].min()
    boost_rounds = cv_results['test-logloss-mean'].argmin()
    print("\tLogLoss {} for {} rounds".format(mean_logloss, boost_rounds))
    if mean_logloss < min_logloss:
        min_logloss = mean_logloss
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, logloss: {}".format(best_params[0], best_params[1], min_logloss))
# Out:
# CV with max_depth=7, min_child_weight=5
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
# 	LogLoss 0.1644544 for 32 rounds
# CV with max_depth=7, min_child_weight=6
# 	LogLoss 0.16413419999999998 for 31 rounds
# CV with max_depth=7, min_child_weight=7
# 	LogLoss 0.1645364 for 27 rounds
# CV with max_depth=8, min_child_weight=5
# 	LogLoss 0.1657498 for 23 rounds
# CV with max_depth=8, min_child_weight=6
# 	LogLoss 0.16510940000000002 for 26 rounds
# CV with max_depth=8, min_child_weight=7
# 	LogLoss 0.1654004 for 25 rounds
# CV with max_depth=9, min_child_weight=5
# 	LogLoss 0.16646180000000002 for 19 rounds
# CV with max_depth=9, min_child_weight=6
# 	LogLoss 0.1662188 for 25 rounds
# CV with max_depth=9, min_child_weight=7
# 	LogLoss 0.1654766 for 28 rounds
# Best params: 7, 6, logloss: 0.16413419999999998

# %%
params['max_depth'] = best_params[0]
params['min_child_weight'] = best_params[1]

# %%
gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

# %%
min_logloss = float("Inf")
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'logloss'},
        early_stopping_rounds=100
    )
    # Update best score
    mean_logloss = cv_results['test-logloss-mean'].min()
    boost_rounds = cv_results['test-logloss-mean'].argmin()
    print("\tMAE {} for {} rounds".format(mean_logloss, boost_rounds))
    if mean_logloss < min_logloss:
        min_logloss = mean_logloss
        best_params = (subsample,colsample)
print("Best params: {}, {}, Logloss: {}".format(best_params[0], best_params[1], min_logloss))
# Out:
# CV with subsample=1.0, colsample=1.0
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
# 	MAE 0.16413419999999998 for 31 rounds
# CV with subsample=1.0, colsample=0.9
# 	MAE 0.16419539999999996 for 35 rounds
# CV with subsample=1.0, colsample=0.8
# 	MAE 0.1650478 for 28 rounds
# CV with subsample=1.0, colsample=0.7
# 	MAE 0.1643904 for 31 rounds
# CV with subsample=0.9, colsample=1.0
# 	MAE 0.164679 for 35 rounds
# CV with subsample=0.9, colsample=0.9
# 	MAE 0.164777 for 32 rounds
# CV with subsample=0.9, colsample=0.8
# 	MAE 0.1645258 for 30 rounds
# CV with subsample=0.9, colsample=0.7
# 	MAE 0.1648032 for 30 rounds
# CV with subsample=0.8, colsample=1.0
# 	MAE 0.1652816 for 27 rounds
# CV with subsample=0.8, colsample=0.9
# 	MAE 0.16506 for 28 rounds
# CV with subsample=0.8, colsample=0.8
# 	MAE 0.1648544 for 27 rounds
# CV with subsample=0.8, colsample=0.7
# 	MAE 0.1648554 for 30 rounds
# CV with subsample=0.7, colsample=1.0
# 	MAE 0.16691280000000003 for 23 rounds
# CV with subsample=0.7, colsample=0.9
# 	MAE 0.1666096 for 27 rounds
# CV with subsample=0.7, colsample=0.8
# 	MAE 0.1660376 for 27 rounds
# CV with subsample=0.7, colsample=0.7
# 	MAE 0.1662582 for 34 rounds
# Best params: 1.0, 1.0, Logloss: 0.16413419999999998

# %%
params['subsample'] = best_params[0]
params['colsample_bytree'] = best_params[1]

# %%
# %time
# This can take some time…
min_logloss = float("Inf")
best_params = None
for eta in [.3, .2, .1, .05, .01, .005]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    # %time cv_results = xgb.cv(params,dtrain,num_boost_round=num_boost_round,seed=42,nfold=5,metrics=['logloss'],early_stopping_rounds=100)
    # Update best score
    mean_logloss = cv_results['test-logloss-mean'].min()
    boost_rounds = cv_results['test-logloss-mean'].argmin()
    print("\tLogloss {} for {} rounds\n".format(mean_logloss, boost_rounds))
    if mean_logloss < min_logloss:
        min_logloss = mean_logloss
        best_params = eta
        
print("Best params: {}, Logloss: {}".format(best_params, min_logloss))
# Out:
# Wall time: 0 ns
# CV with eta=0.3
# Wall time: 10.8 s
# 	Logloss 0.16413419999999998 for 31 rounds
#
# CV with eta=0.2
# C:\Users\User\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning:
# The current behaviour of 'Series.argmin' is deprecated, use 'idxmin'
# instead.
# The behavior of 'argmin' will be corrected to return the positional
# minimum in the future. For now, use 'series.values.argmin' or
# 'np.argmin(np.array(values))' to get the position of the minimum
# row.
#   del sys.path[0]
# Wall time: 12.3 s
# 	Logloss 0.1642024 for 51 rounds
#
# CV with eta=0.1
# Wall time: 18.7 s
# 	Logloss 0.1636316 for 129 rounds
#
# CV with eta=0.05
# Wall time: 27.3 s
# 	Logloss 0.16340179999999999 for 250 rounds
#
# CV with eta=0.01
# Wall time: 1min 23s
# 	Logloss 0.163799 for 997 rounds
#
# CV with eta=0.005
# Wall time: 1min 22s
# 	Logloss 0.1683012 for 998 rounds
#
# Best params: 0.05, Logloss: 0.16340179999999999

# %%
params['eta'] = best_params

# %%
params
# Out:
# {'max_depth': 7,
#  'min_child_weight': 6,
#  'eta': 0.05,
#  'subsample': 1.0,
#  'colsample_bytree': 1.0,
#  'objective': 'reg:logistic',
#  'eval_metric': 'logloss'}

# %%
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")],
    early_stopping_rounds=100
)
# Out:
# [0]	Test-logloss:0.655004
# Will train until Test-logloss hasn't improved in 100 rounds.
# [1]	Test-logloss:0.620502
# [2]	Test-logloss:0.589532
# [3]	Test-logloss:0.56084
# [4]	Test-logloss:0.535029
# [5]	Test-logloss:0.510897
# [6]	Test-logloss:0.489159
# [7]	Test-logloss:0.469022
# [8]	Test-logloss:0.450155
# [9]	Test-logloss:0.4326
# [10]	Test-logloss:0.416684
# [11]	Test-logloss:0.401999
# [12]	Test-logloss:0.38823
# [13]	Test-logloss:0.375474
# [14]	Test-logloss:0.363448
# [15]	Test-logloss:0.352305
# [16]	Test-logloss:0.341907
# [17]	Test-logloss:0.33216
# [18]	Test-logloss:0.323069
# [19]	Test-logloss:0.314479
# [20]	Test-logloss:0.306531
# [21]	Test-logloss:0.299034
# [22]	Test-logloss:0.291686
# [23]	Test-logloss:0.284872
# [24]	Test-logloss:0.278449
# [25]	Test-logloss:0.272323
# [26]	Test-logloss:0.26662
# [27]	Test-logloss:0.261272
# [28]	Test-logloss:0.256209
# [29]	Test-logloss:0.2512
# [30]	Test-logloss:0.24656
# [31]	Test-logloss:0.242378
# [32]	Test-logloss:0.238316
# [33]	Test-logloss:0.234559
# [34]	Test-logloss:0.23112
# [35]	Test-logloss:0.227774
# [36]	Test-logloss:0.224704
# [312]	Test-logloss:0.165392
# [313]	Test-logloss:0.165383
# [314]	Test-logloss:0.165385
# [315]	Test-logloss:0.165409
# [316]	Test-logloss:0.16544
# [317]	Test-logloss:0.165446
# [318]	Test-logloss:0.165446
# [319]	Test-logloss:0.165458
# [320]	Test-logloss:0.165462
# [321]	Test-logloss:0.165476
# [322]	Test-logloss:0.165483
# [323]	Test-logloss:0.165489
# [324]	Test-logloss:0.165488
# [325]	Test-logloss:0.165535
# [326]	Test-logloss:0.165531
# [327]	Test-logloss:0.165516
# [328]	Test-logloss:0.165523
# [329]	Test-logloss:0.165495
# [330]	Test-logloss:0.165541
# [331]	Test-logloss:0.165546
# [332]	Test-logloss:0.165553
# [333]	Test-logloss:0.16557
# [334]	Test-logloss:0.165603
# [335]	Test-logloss:0.165605
# [336]	Test-logloss:0.165634
# [337]	Test-logloss:0.165643
# [338]	Test-logloss:0.165645
# [339]	Test-logloss:0.165678
# [340]	Test-logloss:0.165702
# [341]	Test-logloss:0.165673
# [342]	Test-logloss:0.165743
# [343]	Test-logloss:0.165768
# [344]	Test-logloss:0.165784
# [345]	Test-logloss:0.165781
# [346]	Test-logloss:0.165819
# [347]	Test-logloss:0.165845
# [348]	Test-logloss:0.16585
# [349]	Test-logloss:0.165844
# [350]	Test-logloss:0.16585
# [351]	Test-logloss:0.165881
# [352]	Test-logloss:0.165867
# [353]	Test-logloss:0.165867
# [354]	Test-logloss:0.165869
# [355]	Test-logloss:0.165869
# [356]	Test-logloss:0.165907
# [357]	Test-logloss:0.16591
# Stopping. Best iteration:
# [257]	Test-logloss:0.164848

# %%
print("Best Logloss: {:.2f} with {} rounds".format(
                 model.best_score,
                 model.best_iteration+1))
# Out:
# Best Logloss: 0.16 with 258 rounds

# %%
boost_round = model.best_iteration+1

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round= boost_round
)

# %%
y_pred = model.predict(dtest)

# %%
precision, recall, thresholds = precision_recall_curve(y_test, y_pred)
 
thresholds = np.append(thresholds, 1)
f1_scores = 2*(precision*recall)/(precision+recall)
plt.step(recall, precision, color='b', alpha=0.4, where='post')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('2-class Precision-Recall curve')
plt.show()

# %%
scrs = pd.DataFrame({'precision' : precision, 'recal' : recall, 'thresholds' : thresholds, 'f1_score':f1_scores})
print("Threshold cutoff: ",scrs.loc[scrs['f1_score'] == scrs.f1_score.max(),'thresholds'].iloc[0])
print("Max F1-score at cut-off : ",scrs.f1_score.max())
scrs.plot(x='thresholds', y='f1_score')
# Out:
# Threshold cutoff:  0.31384849548339844
# Max F1-score at cut-off :  0.5184842883548982

# %%
threshold_cutoff = scrs.loc[scrs['f1_score'] == scrs.f1_score.max(),'thresholds'].iloc[0]

# %%
dtrain = xgb.DMatrix(train_data.drop("is_promoted",axis=1), label=train_data['is_promoted'])
dtest = xgb.DMatrix(test_data)

# %%
model = xgb.train(
    params,
    dtrain,
    num_boost_round= boost_round
)

# %%
def xgb_pred(y, threshold= threshold_cutoff):
    y_bin = [1 if y_cont > threshold else 0 for y_cont in y] # binarizing your output
    return y_bin

# %%
pred = model.predict(dtest)
pred_new  = xgb_pred(pred)

# %%
d = {'employee_id': Emp_ID, 'is_promoted': pred_new}
upload_XGB2 = pd.DataFrame(d)
upload_XGB2.to_csv("upload_XGB2.csv",index=False)
