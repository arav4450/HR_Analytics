# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data = pd.read_csv("train.csv")
test_data = pd.read_csv("test.csv")

# %%
train_data.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
plt.plot(train_data['avg_training_score'],'.')

# %%
plt.scatter(range(len(train_data['avg_training_score'])),train_data['avg_training_score'], c=train_data['is_promoted'])

# %%
train_data[['no_of_trainings','previous_year_rating']].apply(lambda x: plt.scatter(x.index, x, c=x.value_counts()))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4276             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4277                 colors = mcolors.to_rgba_array(c)
#    4278                 n_elem = colors.shape[0]
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba_array(c, alpha)
#     285     for i, cc in enumerate(c):
# --> 286         result[i] = to_rgba(cc, alpha)
#     287     return result
#
# ~\Anaconda3\lib\site-packages\matplotlib\colors.py in to_rgba(c, alpha)
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#
# ...

# %%
train_data['education'].isnull().unique()
# Out:
# array([False,  True])

# %%
train_data['education'].value_counts()
# Out:
# Bachelor's          36669
# Master's & above    14925
# Below Secondary       805
# Name: education, dtype: int64

# %%
plt.scatter(range(len(train_data['education'])),'.', c= [0,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-60daae2209ad> in <module>
# ----> 1 plt.scatter(range(len(train_data['education'])),'.', c= [0,1,2,3])
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2839         verts=verts, edgecolors=edgecolors,
#    2840         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2841         None else {}), **kwargs)
#    2842     sci(__ret)
#    2843     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
# ...
